# %%
import pandas as pd
import numpy as np
from requests_html import HTML
from string import punctuation
from nltk.corpus import stopwords
from collections import Counter

# %%
all_question = pd.read_csv('/Users/zhang/MscProject_tweak2vec/data_stacksample/Questions.csv',encoding='ISO-8859-1')
all_tag = pd.read_csv('/Users/zhang/MscProject_tweak2vec/data_stacksample/Tags.csv',encoding='ISO-8859-1')

# %%
# corpus r:50k   py:50k   js:50k   cpp:25k   php:25k

cpp_tag = all_tag[all_tag.Tag=='c++']
cpp_question = pd.merge(cpp_tag,all_question,on='Id')

js_tag = all_tag[all_tag.Tag=='javascript']
js_question = pd.merge(js_tag,all_question,on='Id')

php_tag = all_tag[all_tag.Tag=='php']
php_question = pd.merge(php_tag,all_question,on='Id')

# %%
r_question = pd.read_csv('/Users/zhang/MscProject_tweak2vec/rquestions/Questions.csv', usecols=['Title','Body'])
r_question
# Out:
#                                                     Title  \
# 0               How to access the last value in a vector?
# 1       Worse sin: side effects or passing massive obj...
# 2                    Explain the quantile() function in R
# 3                      How to test for the EOF flag in R?
# 4       Is there an R package for learning a Dirichlet...
# 5                             Optimization packages for R
# 6                              Thinking in Vectors with R
# 7           Vectorize my thinking: Vector Operations in R
# 8                               Is R a compiled language?
# 9                                     Filtering data in R
# 10         Operating with time intervals like 08:00-08:15
# 11      What's the easiest way to install 100s of file...
# 12                     csv file with multiple time-series
# 13      Does R have quote-like operators like Perl's q...
# 14      Writing a GUI for the BRCAPRO Cancer Gene Risk...
# 15                           Sort the X axis in a barplot
# 16       what is the best practice of handling time in R?
# 17      What is the best way to avoid passing a data f...
# 18                                What is the Y function?
# 19               How can I remove an element from a list?
# 20                      Cumulative Plot with Given X-Axis
# 21        Column Stores: Comparing Column Based Databases
# 22      How expensive is it to compute the eigenvalues...
# 23      How do I color edges or draw rects correctly i...
# 24                   R Random Forests Variable Importance
# 25                       Plots without titles/labels in R
# 26      Finding row index containing maximum value usi...
# 27                             Calculating moving average
# 28      Suppressing "null device" output with R in bat...
# 29      What's the best way to use R scripts on the co...
# ...                                                   ...
# 189900  R Lattice / LatticeExtra combine Barplot with ...
# 189901                          A binning procedure in R?
# 189902                sorting data to provide top entries
# 189903          R: gstat: Error in fit.variogram function
# 189904                How to extract values from for loop
# 189905            Is there a way to get the antilog in R?
# 189906                Error in group_by function in dplyr
# 189907  Export from ggplot2 dark theme with no white b...
# 189908  adding string at the end of a string for date ...
# 189909                       density curve plot in ggplot
# 189910  Replacing punctuation in string in different w...
# 189911         R: Plot of frequency of features per class
# 189912  Create a corrplot from continuous and discrete...
# 189913                 R: Plotting Confidence Bands Issue
# 189914  Create many subsets of raster stacks from larg...
# 189915       Refer to several dataframes by variable in R
# 189916                How to draw multiple pie chart in r
# 189917         How can I keep User ID using Rtsne library
# 189918  easier way to plot correlation matrix in R wit...
# 189919  How to create a ggplot 2 spaghetti plot for a ...
# 189920     Extracting the Row Number of the Nth Occurence
# 189921  How to transpose a data frame by group using r...
# 189922   Invalid results while performing difference in R
# 189923  ggplot: add multiline text annotation outside ...
# 189924       Text File in R not loading all the text in R
# 189925  GET command in httr not returning anything aft...
# 189926  R-shiny: Discrete value supplied to continuous...
# 189927  Confidence interval for quantile regression us...
# 189928      Time lag analysis on list of imputed datasets
# 189929  How do I conditionally format text in Shiny gi...
#
#                                                      Body
# 0       <p>Suppose I have a vector that is nested in a...
# 1       <p>I have a function inside a loop inside a fu...
# 2       <p>I've been mystified by the R quantile funct...
# 3       <p>How can I test for the <code>EOF</code> fla...
# 4       <p>I'm looking for a an <code>R</code> package...
# 5       <p>Does anyone know of any optimization packag...
# 6       <p>I know that R works most efficiently with v...
# 7       <p>So earlier I answered my own question on th...
# 8       <p>I can't find it anywhere on the web (and I ...
# 9       <p>I have a CSV of file of data that I can loa...
# 10      <p>I would like to import a time-series where ...
# 11      <p>I have a standard c# application that acts ...
# 12      <p>I've imported a csv file with lots of colum...
# 13      <p>Anyone know if R has quote-like operators l...
# 14      <p>I think this is a completely unique questio...
# 15      <p>I have binned data that looks like this:</p...
# 16      <p>I am working with a survey dataset. It has ...
# 17      <p>I have 12 data frames to work with. They ar...
# 18      <p>A friend of mine asked me if I understood t...
# 19      <p>I have a list and I want to remove a single...
# 20      <p>I have data that looks like this.\nIn which...
# 21      <p>I've really been struggling to make SQL Ser...
# 22      <p>How expensive is it to compute the eigenval...
# 23      <p>I generated <a href="http://farm4.static.fl...
# 24      <p>I am trying to use the random forests packa...
# 25      <p>In <a href="http://www.r-project.org/" rel=...
# 26      <p>Given the following matrix lets assume I wa...
# 27      <p>I'm trying to use R to calculate the moving...
# 28      <p>I have a number of bash scripts which invok...
# 29      <p>It's very convenient to have R scripts for ...
# ...                                                   ...
# 189900  <p><strong>Goal:</strong> I want to create a 3...
# 189901  <p>I am struggling with putting into an R code...
# 189902  <p>I have a table like below. Each row has sto...
# 189903  <p>I am trying to fit a variogram model using ...
# 189904  <p>My code is given below. The code produces <...
# 189905  <p>I've been given a data set and have inputte...
# 189906  <p>I've looked through the related dplyr quest...
# 189907  <p>I want my plots to have dark background to ...
# 189908  <p><strong>My code:</strong></p>\n\n<pre><code...
# 189909  <p>I am new in ggplot and I am trying to draw ...
# 189910  <p>I have a data.frame with a large number of ...
# 189911  <p>I have a data frame similar to the matrix b...
# 189912  <p>I believe the issue is in using three colum...
# 189913  <p>I am trying to plot confidence bands for a ...
# 189914  <p>Having a difficult time conceptualization t...
# 189915  <p>I'm trying to loop through about 5 datafram...
# 189916  <p>I want to draw a multiple pie chart using R...
# 189917  <p>I want to use T-SNE to visualize user's var...
# 189918  <p>I have a data frame look like:</p>\n\n<pre>...
# 189919  <p>I have data that looks like this </p>\n\n<p...
# 189920  <p>Is there an easy way (or any way) to extrac...
# 189921  <h1>Problem</h1>\n\n<p>I have 3 cars (grouping...
# 189922  <p>I have a data frame created using csv file....
# 189923  <p>I want to add a textbox of 10 separate, sta...
# 189924  <p>When I upload a file a text file into R the...
# 189925  <p>I'm trying to access NBA's stats api which ...
# 189926  <p>So I am using mpg dataset to practice my R-...
# 189927  <p>I am trying to get the five types of bootst...
# 189928  <p>My question and data is similar to the post...
# 189929  <p>I am really stumped. Hopefully someone has ...
#
# [189930 rows x 2 columns]

# %%
py_question = pd.read_csv('/Users/zhang/MscProject_tweak2vec/pythonquestions/Questions.csv',encoding='ISO-8859-1',usecols=['Title','Body'])
py_question
# Out:
#                                                     Title  \
# 0       How can I find the full path to a font from it...
# 1                 Get a preview JPEG of a PDF on Windows?
# 2       Continuous Integration System for a Python Cod...
# 3          cx_Oracle: How do I iterate over a result set?
# 4       Using 'in' to match an attribute of Python obj...
# 5                                   Class views in Django
# 6                                        Python and MySQL
# 7              How do I use Python's itertools.groupby()?
# 8          Adding a Method to an Existing Object Instance
# 9           How do you express binary literals in Python?
# 10                 Any experiences with Protocol Buffers?
# 11      How do I make a menu that does not require the...
# 12        How to check what OS am I running on in Python?
# 13      Python: what is the difference between (1,2,3)...
# 14      File size differences after copying a file to ...
# 15      How can I create a directly-executable cross-p...
# 16      Calling a function of a module from a string w...
# 17      Programmatically talking to a Serial Port in O...
# 18      How to sell Python to a client/boss/person wit...
# 19      How do you set up Python scripts to work in Ap...
# 20      Does anyone have experience creating a shared ...
# 21      Cross Platform, Language Agnostic GUI Markup L...
# 22      Convert Bytes to Floating Point Numbers in Python
# 23               Python, Unicode, and the Windows console
# 24        Get size of a file before downloading in Python
# 25          Best way to abstract season/show/episode data
# 26            Pylons error - 'MySQL server has gone away'
# 27                            How to use Xpath in Python?
# 28                    Accessing mp3 Meta-Data with Python
# 29      How do I treat an integer as an array of bytes...
# ...                                                   ...
# 607252  Python code for changing relative links in a w...
# 607253  python matplotlib : assign cmap to make multip...
# 607254                      Django choices and dictionary
# 607255  how can I exit a tkinter window after changing...
# 607256  converting non-numeric to numeric value using ...
# 607257          Numpy installation issues with Miniconda2
# 607258       Collision Between two sprites - Python 3.5.2
# 607259              pyLDAvis package without proxy setup?
# 607260  How to do curvefitting using scipy.optimize.cu...
# 607261  How to remove elements from a nested json with...
# 607262  Python Array Reshaping Issue to Array with Sha...
# 607263  Different result for String and Integers using...
# 607264  Django Internal Server 500 Error AWS Elastic-B...
# 607265                Restarting a function in Python 3.4
# 607266         can't assign to function call Error-Python
# 607267  How to get the item created from dropEvent on ...
# 607268  How do you make it so that a function returns ...
# 607269      Add text to scatter point using python gmplot
# 607270  How to *correctly* read data from csv's into T...
# 607271        Removing a subarray after using numpy.split
# 607272  error handling with BeautifulSoup when scraped...
# 607273  Q: What is Big-O complexity of random.choice(l...
# 607274  How can I implement a stopwatch in my socket P...
# 607275  finding cubed root using delta and epsilon in ...
# 607276           Trouble installing pillow for Windows 10
# 607277  How to execute multiline python code from a ba...
# 607278  How to get google reCaptcha image source using...
# 607279      Updating an ManyToMany field with Django rest
# 607280                                Most possible pairs
# 607281            Theano operations returning odd results
#
#                                                      Body
# 0       <p>I am using the Photoshop's javascript API t...
# 1       <p>I have a cross-platform (Python) applicatio...
# 2       <p>I'm starting work on a hobby project with a...
# 3       <p>There are several ways to iterate over a re...
# 4       <p>I don't remember whether I was dreaming or ...
# 5       <p><a href="http://www.djangoproject.com/">Dja...
# 6       <p>I can get Python to work with Postgresql bu...
# 7       <p>I haven't been able to find an understandab...
# 8       <p>I've read that it is possible to add a meth...
# 9       <p>How do you express an integer as a binary n...
# 10      <p>I was just looking through some information...
# 11      <p>I've got a menu in Python. That part was ea...
# 12      <p>What do I need to look at to see if I'm on ...
# 13      <p>In many places, <code>(1,2,3)</code> and <c...
# 14      <p>I have created a PHP-script to update a web...
# 15      <p>Python works on multiple platforms and can ...
# 16      <p>What is the best way to go about calling a ...
# 17      <p>I have a Prolite LED sign that I like to se...
# 18      <p>When asked to create system XYZ and you ask...
# 19      <p>I tried to follow a couple of googled up tu...
# 20      <p>A researcher has created a small simulation...
# 21      <p>I learned Swing back in the day but now I'v...
# 22      <p>I have a binary file that I have to parse a...
# 23      <p>When I try to print a Unicode string in a W...
# 24      <p>I'm downloading an entire directory from a ...
# 25      <p>Basically, I've written an API to www.thetv...
# 26      <p>[I hope this isn't too obscure&hellip; I'll...
# 27      <p>What is the library? Is there a full implem...
# 28      <p>What is the best way to retrieve mp3 metada...
# 29      <p>I'm trying to decode the result of the Pyth...
# ...                                                   ...
# 607252  <p>I would like make a website that shows cont...
# 607253  <p>I am trying to use matplotlib and seaborn t...
# 607254  <p>I have code</p>\n\n<pre><code>JOBS = 1\nCAT...
# 607255  <p>So I'm trying to make a little battle scene...
# 607256  <p>I am a machine learning beginner and wan't ...
# 607257  <p>I'm on a <code>windows 10</code> machine an...
# 607258  <p>I have an image of a ufo and a missile. I'm...
# 607259  <p>I would like to use pyLDAvis to visualize t...
# 607260  <p>I am quite new to Python. I wanted to do a ...
# 607261  <p>I have the following json:</p>\n\n<p>{</p>\...
# 607262  <p>I have this error and I'm not sure how do I...
# 607263  <p><strong>EDIT:</strong>\nAs @Alfe suggested ...
# 607264  <p>How do I fix the Django Internal Server 500...
# 607265  <p>I need help for my python assignment. We ha...
# 607266  <p>So I'm working on a project to create a pos...
# 607267  <p>So I'm trying to copy a selected item from ...
# 607268  <p>Basically I have a tuple which has 5 tuples...
# 607269  <p>I plotted some points on google maps using ...
# 607270  <p>I came across <a href="http://stackoverflow...
# 607271  <p>Title kinda says it all, I'm trying to make...
# 607272  <p>I'm totally noob to python so please forgiv...
# 607273  <p>What is Big-O complexity of random.choice(l...
# 607274  <p>I am creating a very simple ping program in...
# 607275  <p>I am trying to write a program that finds c...
# 607276  <p>Having issues installing Pillow for python ...
# 607277  <p>I need to extend a shell script (bash). As ...
# 607278  <p>I understood that reCaptcha loads a new fra...
# 607279  <p>I'm trying to set up this API so I can use ...
# 607280  <p>Given a list of values, and information on ...
# 607281  <p>So I'm trying to learn how to use Theano an...
#
# [607282 rows x 2 columns]

# %%
r_question['Text'] = r_question['Title'] + r_question['Body']
py_question['Text'] = py_question['Title'] + py_question['Body']
js_question['Text'] = js_question['Title'] + js_question['Body']
cpp_question['Text'] = cpp_question['Title'] + cpp_question['Body']
php_question['Text'] = php_question['Title'] + php_question['Body']

# %%
r_question_list = np.array(r_question['Text'])
py_question_list = np.array(py_question['Text'])
js_question_list = np.array(js_question['Text'])
cpp_question_list = np.array(cpp_question['Text'])
php_question_list = np.array(php_question['Text'])

# %%
def clean_doc2tokens(data):
    doc = HTML(html=data).text #remove html label
    doc = ''.join(' ' if c in punctuation else c for c in doc) #remove punctuations
    tokens = doc.split()
    tokens = [w.lower() for w in tokens]
    tokens = [w for w in tokens if w.isalpha()]
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    return tokens

def tokens2doc(tokens, vocab_list):
    tokens = ['UNK' if w not in vocab_list else w for w in tokens]
    return ' '.join(tokens)

def update_vocab(tokens, vocab):
    tokens = clean_doc2tokens(data)
    vocab.update(tokens)
    

# create vocab (clean data, split tokens)
# create clean corpus (clean data again, replace UNK)
# train word vectors

# %%
def create_vocab(corpus):
    corpus_nounk = list()
    vocab = Counter()
    loop = 1
    for data in corpus:
        if loop%10000 == 0:
            print(loop)
        tokens = clean_doc2tokens(data)
        corpus_nounk.append(tokens)
        vocab.update(tokens)
        loop = loop + 1
    return corpus_nounk,vocab

def create_vocab_list(vocab, min_occurrence):
    vocab_freq_list = [[k,c] for k,c in vocab.most_common() if c >= min_occurrence]
    return vocab_freq_list

def create_clean_corpus(corpus_nounk, vocab_list):
    corpus_withunk = list()
    loop = 1
    for data in corpus_nounk:
        if loop%10000 == 0:
            print(loop)
        loop = loop + 1
        tokens = ['UNK' if w not in vocab_list else w for w in data]
        corpus_withunk.append(tokens)
    return corpus_withunk

# %%
# corpus r:100k   py:100k   js:50k   cpp:25k   php:25k

min_occurrence = 2

cop_r = r_question_list[0:50000]
cop_py = py_question_list[0:50000]
cop_js = js_question_list[0:50000]
cop_cpp = cpp_question_list[0:25000]
cop_php = php_question_list[0:25000]
cop = (cop_r, cop_py, cop_js, cop_cpp, cop_php)

corpus = np.concatenate(cop, axis=0)

# %%
len(corpus)
# Out:
# 200000

# %%
np.save('stack_vocab.npy',np.array(vocab_freq_list))

# %%
corpus_nounk, vocab = create_vocab(corpus)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000

# %%
vocab_freq_list = create_vocab_list(vocab, min_occurrence)
vocab_list = [w[0] for w in vocab_freq_list]
vocab_list.append('UNK')

# %%
corpus_withunk = create_clean_corpus(corpus_nounk, vocab_list)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000

# %%
corpus_withunk = np.load('/Users/zhang/MscProject_tweak2vec/corpus/stack_corpus_unk.npy')

# %%
len(corpus_withunk)
# Out:
# 200000
