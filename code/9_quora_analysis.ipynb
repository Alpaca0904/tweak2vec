# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KDTree
import datetime, time, json
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from keras.models import Model
from keras.layers import Input, TimeDistributed, Dense, Lambda, concatenate, Dropout, BatchNormalization
from keras.layers.embeddings import Embedding
from keras.regularizers import l2
from keras.callbacks import Callback, ModelCheckpoint, History
from keras import backend as K
from keras.preprocessing.sequence import pad_sequences
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
wordlist = np.load('/Users/zhang/MscProject_tweak2vec/corpus/quora_vocab5.npy').tolist()
wordlist.append(['UNK',0])
word2idx = {w[0]: wordlist.index(w) for w in wordlist }
idx2word = {wordlist.index(w): w[0] for w in wordlist }

# %%
embed_reg = np.load('/Users/zhang/MscProject_tweak2vec/word2vecModel/quora/tokens/w2v_pivotsfull_alpha10_5m.npy')
embed_bas = np.load('/Users/zhang/MscProject_tweak2vec/word2vecModel/quora/tokens/w2v_quora_5m.npy')
embed_pre = np.load('/Users/zhang/MscProject_tweak2vec/word2vecModel/quora/tokens/w2v_quoragoogle_50d.npy')

# %% [markdown]
# ### search nearest neighbours

# %%
def K_neighbour(embed_set, word, k):
    tree = KDTree(embed_set, leaf_size=100)
    vec = embed_set[word2idx[word]]
    dists, inds = tree.query([vec], k)
    inds = inds.reshape(k,)
    near_words = [idx2word[i] for i in list(inds)]
    return near_words

# %%
w = 'history'
near_words_seg = K_neighbour(embed_seg, w, 6)
near_words_bas = K_neighbour(embed_bas, w, 6)
near_words_pre = K_neighbour(embed_pre, w, 6)
print('SEG-----',near_words_seg)
print('BAS-----',near_words_bas)
print('PRE-----',near_words_pre)
# Out:
# SEG----- ['history', 'today', 'part', 'most', 'significant', 'achievements']
# BAS----- ['history', 'events', 'modern', 'relevant', 'recent', 'involved']
# PRE----- ['history', 'most', 'century', 'one', 'decade', 'decades']

# %% [markdown]
# ### compute cosin similarity

# %% [markdown]
# ### get test prediction

# %%
def Max_BoE(word_embedding):

    question1 = Input(shape=(max_sentence_len,))
    question2 = Input(shape=(max_sentence_len,))



    q1 = Embedding(  input_dim=vocab_size, 
                     output_dim=embed_dim, 
                     weights=[word_embedding], 
                     input_length=max_sentence_len, 
                     trainable=False)(question1)
    q1 = TimeDistributed(Dense(embed_dim, activation='relu'))(q1)
    q1 = Lambda(lambda x: K.max(x, axis=1), output_shape=(embed_dim, ))(q1)

    q2 = Embedding(  input_dim=vocab_size, 
                     output_dim=embed_dim, 
                     weights=[word_embedding], 
                     input_length=max_sentence_len, 
                     trainable=False)(question2)
    q2 = TimeDistributed(Dense(embed_dim, activation='relu'))(q2)
    q2 = Lambda(lambda x: K.max(x, axis=1), output_shape=(embed_dim, ))(q2)

    merged = concatenate([q1,q2])
    merged = Dense(200, activation='relu')(merged)
    merged = Dropout(dropout_rate)(merged)
    merged = BatchNormalization()(merged)
    merged = Dense(200, activation='relu')(merged)
    merged = Dropout(dropout_rate)(merged)
    merged = BatchNormalization()(merged)
    merged = Dense(200, activation='relu')(merged)
    merged = Dropout(dropout_rate)(merged)
    merged = BatchNormalization()(merged)
    merged = Dense(200, activation='relu')(merged)
    merged = Dropout(dropout_rate)(merged)
    merged = BatchNormalization()(merged)

    is_duplicate = Dense(1, activation='sigmoid')(merged)

    model = Model(inputs=[question1,question2], outputs=is_duplicate)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
current_embed = {}
current_embed['REG'] = np.load("/Users/zhang/MscProject_tweak2vec/word2vecModel/quora/tokens/w2v_cat_reg_5m.npy")
current_embed['BAS'] = np.load("/Users/zhang/MscProject_tweak2vec/word2vecModel/quora/tokens/w2v_quora_5m.npy")
current_embed['PRE'] = np.load("/Users/zhang/MscProject_tweak2vec/word2vecModel/quora/tokens/w2v_quoragoogle_50d.npy")

# %%
quora_corpus = np.load("/Users/zhang/MscProject_tweak2vec/corpus/quora_corpus_int5.npy")
labels = np.load("/Users/zhang/MscProject_tweak2vec/corpus/quora_labels.npy")
question1 = []
question2 = []
for n in range(int(len(quora_corpus)/2)):
    question1.append(quora_corpus[2*n])
    question2.append(quora_corpus[2*n+1])
    
# hyperparameter setup
max_sentence_len = 25
embed_dim = 50
dropout_rate = 0.1
vocab_size = len(current_embed)
    
q1_data = pad_sequences(question1, maxlen=25)
q2_data = pad_sequences(question2, maxlen=25)
questions = np.stack((q1_data, q2_data), axis=1)
X_train, X_test, y_train, y_test = train_test_split(questions, labels, test_size=0.1, random_state=2018)
Q1_train = X_train[:,0]
Q2_train = X_train[:,1]
Q1_test = X_test[:,0]
Q2_test = X_test[:,1]

# %%
weight_file = {}

weight_file['BAS'] = '/Users/zhang/MscProject_tweak2vec/Max_BOE_weights/quora_5m_weights.h5'
weight_file['REG'] = '/Users/zhang/MscProject_tweak2vec/Max_BOE_weights/reg_5m_weights.h5'
weight_file['PRE'] = '/Users/zhang/MscProject_tweak2vec/Max_BOE_weights/pretrain_50d_weights.h5'

# %%
def return_acc(w_file, embed):
    MODEL_WEIGHTS_FILE = w_file
    model = Max_BoE(embed)
    model.load_weights(MODEL_WEIGHTS_FILE)
    loss, accuracy = model.evaluate([Q1_test[:10000], Q2_test[:10000]], y_test[:10000], verbose=0)
    pred_y = model.predict([Q1_test[:10000], Q2_test[:10000]], verbose=0)
    pred_y = pred_y.reshape(len(pred_y),)
    #pred_y = [1 if i <0.5 else 0 for i in pred_y]
    acc_y = np.abs(pred_y -y_test[:10000])
    acc = np.array([1 if i < 0.5 else 0 for i in acc_y ]).reshape(len(acc_y),1)
    return acc

# %%
acc_list = {}
pred_list = {}
acc_list['REG'] = return_acc(weight_file['REG'], current_embed['REG'])
acc_list['BAS'] = return_acc(weight_file['BAS'], current_embed['BAS'])
acc_list['PRE'] = return_acc(weight_file['PRE'], current_embed['PRE'])

# %%
confusion_matrix(y_test, y_test, labels=[0,1])
# Out:
# array([[25495,     0],
#        [    0, 14934]])

# %%
acc_cat = np.concatenate((acc_list['REG'], acc_list['BAS'], acc_list['PRE']),axis=1)

# %%
a=0

for i in range(len(acc_cat)):
    q1 = [idx2word[w] if w!=0 else '' for w in Q1_test[i]]  
    q2 = [idx2word[w] if w!=0 else '' for w in Q2_test[i]]
    
    q1 = ' '.join(q1)
    q2 = ' '.join(q2)

    
    if np.array_equal(acc_cat[i],[1,0,0]):
        
        print('indix:{0},results:{1}'.format(i,acc_cat[i]))
        print('question1:',q1)
        print('question2:',q2)
# Out:
# indix:85,results:[1 0 0]
# question1:              who are top fea service providers provide accurate handling analysis services globally
# question2:              who are top fea service providers provide accurate modal analysis services globally
# indix:154,results:[1 0 0]
# question1:                      why reddit better quora
# question2:                      site better reddit quora
# indix:185,results:[1 0 0]
# question1:               why do we have stage fright how do we overcome it
# question2:                     best way overcome stage fear
# indix:214,results:[1 0 0]
# question1:                    my dad cheats should  do
# question2:               recently found my dad cheating on my mom should  do
# indix:226,results:[1 0 0]
# question1:                     best way advertise your business
# question2:                     best way advertise business offline
# indix:255,results:[1 0 0]
# question1:                    cooler better violin piano your opinion
# question2:            in your opinion better learning rhythmic ability in music guitar electric bass drums piano
# indix:269,results:[1 0 0]
# question1:                    how can one learn trust again
# question2:                     how do you learn trust
# indix:278,results:[1 0 0]
# question1:             ajay chandrakar s seeks in direction becoming greatest eco tourism hub in chhattisgarh
# question2:             ajay chandrakar s points towards turning into greatest eco tourism hub in chhattisgarh
# indix:310,results:[1 0 0]
# question1:                      are craziest facts microsoft
# question2:                    are some amazing facts microsoft windows
# indix:325,results:[1 0 0]
# question1:                   why do religions exist their purpose society
# question2:                god does not exist purpose do we have point living
# indix:335,results:[1 0 0]
# question1:                     how does morse code work
# question2:                        morse code
# indix:372,results:[1 0 0]
# question1:                     how do  go vegan
# question2:                    how did you decide go vegan
# indix:380,results:[1 0 0]
# question1:            would any women out there date man 3 4 inches shorter you without heels
# question2:                  would you go out with man shorter you
# indix:442,results:[1 0 0]
# question1:                   iron man vs superman who would win
# question2:                 who would win in battle between superman iron man
# indix:444,results:[1 0 0]
# question1:           how much dirt there in whole measure two feet by five feet by four feet
# question2:           how much dirt there in hole measures two feet by three feet by four feet
# indix:570,results:[1 0 0]
# question1:                     would you prefer tea coffee
# question2:                   beverages why do you prefer tea coffee
# indix:578,results:[1 0 0]
# question1:               you didn t have work money would you rather enjoy doing
# question2:                 would you do you didn t have work living
# indix:586,results:[1 0 0]
# question1:                       was ottoman empire
# question2:                     where did ottoman empire originate
# indix:591,results:[1 0 0]
# question1:                    it true redbull bad your health
# question2:                      drinking redbull bad health
# indix:610,results:[1 0 0]
# question1:                  how can you check phone number called you
# question2:               how do you find out who phone cell phone number belongs
# indix:618,results:[1 0 0]
# question1:                      function lines latitude longitude
# question2:                    are similarities between lines longitude latitude
# indix:701,results:[1 0 0]
# question1:                  are some best books self help all times
# question2:                     are best books all time
# indix:744,results:[1 0 0]
# question1:                    scope mba operations management in india
# question2:                   how good future operations management in india
# indix:813,results:[1 0 0]
# question1:                 it true UNK nehru grandfather jawaharlal nehru was muslim
# question2:                      was jawaharlal nehru muslim
# indix:876,results:[1 0 0]
# question1:             how do  balance need be comfortable push myself out my comfort zone
# question2:                 are some straight point example getting out comfort zone
# indix:889,results:[1 0 0]
# question1:                      can be basis trust
# question2:                    on basis can we trust history
# indix:906,results:[1 0 0]
# question1:                   best advice you could give yourself now
# question2:                      best advice give yourself
# indix:996,results:[1 0 0]
# question1:                     how long was battle gettysburg
# question2:                how long was battle gettysburg how many casualties were suffered
# indix:1002,results:[1 0 0]
# question1:                   best programming language learn applications use databases
# question2:                  best programming language learn use with website development
# indix:1102,results:[1 0 0]
# question1:                  do you think when you look into mirror
# question2:                    why do you look in mirror
# indix:1204,results:[1 0 0]
# question1:                   difference between working in analytics data science
# question2:                    difference between data science data analysis
# indix:1242,results:[1 0 0]
# question1:                    how iiser kolkata better iiser pune
# question2:                    how iiser pune better iiser kolkata
# indix:1302,results:[1 0 0]
# question1:                    how do  learn chemistry fast
# question2:                     best way easily understand chemistry
# indix:1312,results:[1 0 0]
# question1:                  how do  make money with google adsense
# question2:                 how do  make more money on google adsense
# indix:1374,results:[1 0 0]
# question1:                   how does someone become better problem solver
# question2:               how can  become more creative interdisciplinary in my problem solving
# indix:1384,results:[1 0 0]
# question1:                    are best places visit in ghana
# question2:                     best place in india visit
# indix:1406,results:[1 0 0]
# question1:                       water perfectly colorless
# question2:                       why water colorless
# indix:1438,results:[1 0 0]
# question1:                   how do you lower your blood pressure
# question2:                   how can you lower your blood pressure
# indix:1476,results:[1 0 0]
# question1:                     are best step become ca
# question2:                     how do  pass ca
# indix:1496,results:[1 0 0]
# question1:                      why harley quinn popular
# question2:                      harley quinn becoming mainstream
# indix:1567,results:[1 0 0]
# question1:                  how do  remove bags under my eyes
# question2:                  how can you treat remove bags under eyes
# indix:1589,results:[1 0 0]
# question1:                    how do  make php website
# question2:                  how long does it take make php website
# indix:1607,results:[1 0 0]
# question1:                    how can  make money musician
# question2:                     how do musicians make money
# indix:1653,results:[1 0 0]
# question1:                      modi s india shining
# question2:                    india really changing under pm modi
# indix:1655,results:[1 0 0]
# question1:                      will pakistan destroy india
# question2:                      how pakistan destroying india
# indix:1782,results:[1 0 0]
# question1:                   would happen copyright laws were non existent
# question2:              hypothetical scenaroperating system would world be like there were no copyright laws
# indix:1818,results:[1 0 0]
# question1:                       applicant tracking system
# question2:                      are applicant tracking systems
# indix:1835,results:[1 0 0]
# question1:                    are some weirdest questions on quora
# question2:                   are most annoying types questions on quora
# indix:1844,results:[1 0 0]
# question1:                    do  really need go school
# question2:                    why do we need go school
# indix:1871,results:[1 0 0]
# question1:                       peer peer lending
# question2:                       peer peer lending
# indix:1930,results:[1 0 0]
# question1:                   are best free porn sites provide their
# question2:                      best free pornography site
# indix:1960,results:[1 0 0]
# question1:                  how do  train two year old labrador
# question2:                     how do  train labrador
# indix:2066,results:[1 0 0]
# question1:            how do  prepare advanced financial management paper ca final exams in 2 weeks
# question2:                   best way prepare ca final law audit
# indix:2084,results:[1 0 0]
# question1:                     best position first time sex
# question2:                   are best positions first time anal sex
# indix:2103,results:[1 0 0]
# question1:                 how will girl know whether boy likes her not
# question2:           how can girl know boy interested in her would like be in relationship with her
# indix:2147,results:[1 0 0]
# question1:               are some creative innovative business ideas with less investment in india
# question2:                  are some best business ideas with minimum investment
# indix:2175,results:[1 0 0]
# question1:                    how often should couple have sex
# question2:                    how often should person have sex
# indix:2267,results:[1 0 0]
# question1:                   how do you get rid off UNK
# question2:                     can  get rid emotions
# indix:2335,results:[1 0 0]
# question1:                        geo targeting
# question2:                        geo targeting
# indix:2365,results:[1 0 0]
# question1:                  dating relationship it wrong girl makes first move
# question2:              dating relationships it wrong girl makes first move be friends with guy
# indix:2373,results:[1 0 0]
# question1:                       operational amplifier circuit
# question2:                        operational amplifier
# indix:2385,results:[1 0 0]
# question1:                    s best way shop clothes online
# question2:                    how do  shop clothes online
# indix:2402,results:[1 0 0]
# question1:                   how do  stay motivated self educating
# question2:                how do you stay motivated on daily weekly monthly basis
# indix:2491,results:[1 0 0]
# question1:                        putin weak
# question2:                       putin really bad
# indix:2592,results:[1 0 0]
# question1:                   s best way learn how write articles
# question2:                    how do  write how article
# indix:2615,results:[1 0 0]
# question1:                       are super powers
# question2:                    would you do with super powers
# indix:2668,results:[1 0 0]
# question1:                    nicest thing anyone has done you
# question2:                 nicest thing you personally have ever done another person
# indix:2679,results:[1 0 0]
# question1:                    why condenser used in rankine cycle
# question2:                    why condenser used in UNK cycle
# indix:2735,results:[1 0 0]
# question1:                how can  control my subconscious mind most easily UNK
# question2:                     can  control subconscious mind
# indix:2816,results:[1 0 0]
# question1:                    best scooter in india under 60000
# question2:                   best scooter you have UNK in india
# indix:2825,results:[1 0 0]
# question1:                    how can  make my blog
# question2:                   how do  make my blog popular
# indix:2893,results:[1 0 0]
# question1:                       function in programming
# question2:                        functional programming
# indix:2980,results:[1 0 0]
# question1:                     are movies with best plots
# question2:                    are best movies with plot twist
# indix:3013,results:[1 0 0]
# question1:                     salary it technician at spotify
# question2:                      salary spotify it technician
# indix:3069,results:[1 0 0]
# question1:                       why football popular
# question2:                  why football soccer most popular sport in world
# indix:3091,results:[1 0 0]
# question1:                      are some examples herbivores
# question2:                      are examples herbivorous animals
# indix:3144,results:[1 0 0]
# question1:                     are best mechanical engineering books
# question2:                  are some interesting books mechanical engineer should read
# indix:3173,results:[1 0 0]
# question1:                      autocad still new outdated
# question2:                        autocad outdated
# indix:3193,results:[1 0 0]
# question1:                      ethical hacking certification free
# question2:                     are certification courses ethical hacking
# indix:3276,results:[1 0 0]
# question1:                   how do you define success in life
# question2:                     how does one define success
# indix:3277,results:[1 0 0]
# question1:                    best way avoid procrastinating on internet
# question2:                     how do  avoid procrastinating
# indix:3280,results:[1 0 0]
# question1:                      importance mitochondria in cell
# question2:                      mitochondria are main functions
# indix:3300,results:[1 0 0]
# question1:                 why we do study computer fundamental in software engineering
# question2:                why do we need learn data base in computer engineering
# indix:3308,results:[1 0 0]
# question1:                 it like live in rv other truly mobile home
# question2:                  it like live in rv travel in it
# indix:3354,results:[1 0 0]
# question1:                does it mean dog has diarrhea with blood in it
# question2:               does it mean your dog suffering from diarrhea also UNK blood
# indix:3460,results:[1 0 0]
# question1:                     why are some people quiet
# question2:                   why are some very smart people quiet
# indix:3524,results:[1 0 0]
# question1:                      orgasm percentage women have
# question2:                     percentage women cannot have orgasm
# indix:3535,results:[1 0 0]
# question1:                  how can we use word inertia in sentence
# question2:                  how can word inertia be used in sentence
# indix:3549,results:[1 0 0]
# question1:               how can  get away with promoting my novel on quora
# question2:            my first novel out in print how can  promote it here on quora
# indix:3570,results:[1 0 0]
# question1:                where can  get best label printing work in australia
# question2:             where can  get very affordable price different kinds label printing in australia
# indix:3580,results:[1 0 0]
# question1:                 when ballon d 2016 its telecast details in india
# question2:              tv channel in india will broadcast ballon d 2016 are its timings
# indix:3584,results:[1 0 0]
# question1:                 most common questions in interview fresh graduate civil engineer
# question2:                  are questions in interview fresh graduate civil engineer
# indix:3597,results:[1 0 0]
# question1:             data analytics vs business analytics vs data science difference one should  go
# question2:                 s difference between business analytics data analytics data science
# indix:3663,results:[1 0 0]
# question1:                   how can  keep cilantro from flowering
# question2:                how do  grow cilantro keep it from going seed
# indix:3664,results:[1 0 0]
# question1:                  can you spray paint cardboard best kind use
# question2:                it ok spray paint cardboard how well does it work
# indix:3774,results:[1 0 0]
# question1:                 why does scotland want be independent from u k
# question2:                  why does scotland want separate from united kingdom
# indix:3815,results:[1 0 0]
# question1:                     how does liver filter blood
# question2:                     how do kidneys filter blood
# indix:3847,results:[1 0 0]
# question1:                    why are there no UNK snowstorm
# question2:                    why isn t there lightning blizzard
# indix:3887,results:[1 0 0]
# question1:                    how can we regrow hair naturally
# question2:                   how do  grow my hair naturally
# indix:3891,results:[1 0 0]
# question1:                    funniest video you have ever watched
# question2:                    best video you have ever seen
# indix:3939,results:[1 0 0]
# question1:         going be fate indian economy indians stop buying chinese product whole trade between india china comes end
# question2:            how s indian economy chinese economy affected it closes china product in indian market
# indix:3940,results:[1 0 0]
# question1:                  best way lose 30 pounds in 4 months
# question2:                how can  lose UNK in 4 months without starving
# indix:3961,results:[1 0 0]
# question1:                     how can  remember forget
# question2:                    best way remember not forget later
# indix:4027,results:[1 0 0]
# question1:                  did any you grow up without your parents
# question2:                   are some effects growing up without parents
# indix:4191,results:[1 0 0]
# question1:        have 3 mono amplifiers how do  wire their inputs stereo  have pair stereo one mono outputs
# question2:         have 3 mono amplifiers how do  wire their inputs  have pair stereo one mono outputs
# indix:4199,results:[1 0 0]
# question1:                how can  teen with mental health problems get job
# question2:                  can people with mental health problems get job
# indix:4231,results:[1 0 0]
# question1:                        my yahoo
# question2:                       does yahoo own
# indix:4241,results:[1 0 0]
# question1:                     best way become actuary analyst
# question2:                      best way become actuary
# indix:4258,results:[1 0 0]
# question1:                are there any sources templates stock option agreement with employees
# question2:                 are there any templates employee friendly stock options agreements
# indix:4305,results:[1 0 0]
# question1:                    how does cruise ship stay UNK
# question2:                     how does ship stay UNK
# indix:4317,results:[1 0 0]
# question1:    had sex 2 months ago  had my period last month not month my period 5 days late could  be pregnant
# question2:                  my period 5 days late do  do
# indix:4331,results:[1 0 0]
# question1:                      best book learn valuation
# question2:                    best book learning how valuate company
# indix:4368,results:[1 0 0]
# question1:                 how it like be inside kangaroo s pocket pouch
# question2:                   it like be inside kangaroo s pouch
# indix:4400,results:[1 0 0]
# question1:                  how do  retrieve deleted photos off cellphone
# question2:                 how do  retrieve deleted photos from my computer
# indix:4429,results:[1 0 0]
# question1:                 do you think happens our consciousness when we die
# question2:                      happens consciousness after death
# indix:4452,results:[1 0 0]
# question1:             why do many voters who admit hillary terrible person want vote her anyway
# question2:              does hillary s morality good bad affect whether people choose vote her
# indix:4462,results:[1 0 0]
# question1:                 are chances bjp will win 2017 uttar pradesh elections
# question2:     will upcoming military action by india in late 2016 early 2017 against pakistan help modi win uttar pradesh gujarat loksabha elections
# indix:4498,results:[1 0 0]
# question1:              do we know there s limit how much information brain can store
# question2:                   how much data can human brain store
# indix:4520,results:[1 0 0]
# question1:                   why do people think  am gay
# question2:                 why do people think  am against gay people
# indix:4548,results:[1 0 0]
# question1:                   are best colleges at oxford studying physics
# question2:                   are best colleges physics at oxford university
# indix:4642,results:[1 0 0]
# question1:                  how can we remove stretch marks from stomach
# question2:                how can you get rid stretch marks by losing weight
# indix:4644,results:[1 0 0]
# question1:                why can t barack obama run reelection president in 2016
# question2:                    can obama run again president 2016
# indix:4645,results:[1 0 0]
# question1:                    are differences between c objective c
# question2:                   are some major differences between c c
# indix:4673,results:[1 0 0]
# question1:                weirdest compliment you have ever received how did you respond
# question2:             strangest weirdest funniest most absurd you name it compliment you have received given
# indix:4725,results:[1 0 0]
# question1:                   do girls like smart nerdy geeky guys
# question2:                      do girls like nerds
# indix:4786,results:[1 0 0]
# question1:                        fictitious assets
# question2:                       are fictitious assets
# indix:4787,results:[1 0 0]
# question1:               most embarrassing thing you have done in front person you like
# question2:                 most embarrassing thing you did in front you crush
# indix:4798,results:[1 0 0]
# question1:                       was rum ration
# question2:                 was rum ration purpose did it serve in war
# indix:4836,results:[1 0 0]
# question1:                  how do  remove light scratches from car
# question2:                  are some diy ways remove scratches from car
# indix:4885,results:[1 0 0]
# question1:             hypothetical wars who would win world war 3 none countries use nuclear weapons
# question2:            world war broke out tomorrow who would win there were no nuclear weapons used
# indix:4923,results:[1 0 0]
# question1:                how do you know when you re in wrong relationship
# question2:                 how do you know you are in wrong relationship
# indix:4975,results:[1 0 0]
# question1:                    how do you start ecommerce business
# question2:                    how do  start ecommerce business
# indix:4994,results:[1 0 0]
# question1:                    best headphone under rs 6500 inr
# question2:                     headphone best under inr 5000
# indix:4997,results:[1 0 0]
# question1:                   are people in love with donald trump
# question2:                    why do people love donald trump
# indix:5068,results:[1 0 0]
# question1:                  how do you personally define morality good evil
# question2:                     how do you define morality
# indix:5087,results:[1 0 0]
# question1:                 who bloody mary based on true story behind lady
# question2:                     there true story bloody mary
# indix:5097,results:[1 0 0]
# question1:                best answer question why do you want join indian army
# question2:               best answer recruiter asking why do you want join indian navy
# indix:5129,results:[1 0 0]
# question1:                   how are green spots on potatoes harmful
# question2:                   are green coloured potatoes are harmful health
# indix:5137,results:[1 0 0]
# question1:                can  do after competing b sc in chemistry physics
# question2:                  can  do after b sc with physics
# indix:5182,results:[1 0 0]
# question1:                       trapezoid cyclic quadrilateral
# question2:                       why parallelogram trapezoid
# indix:5189,results:[1 0 0]
# question1:                     easier web designing app development
# question2:                      easier web designing development
# indix:5202,results:[1 0 0]
# question1:                   how do certifications help in career growth
# question2:                    does certification help in career growth
# indix:5209,results:[1 0 0]
# question1:                who would win in fight between silverback gorilla siberian tiger
# question2:                in fight between grizzly bear silverback gorilla who would win
# indix:5212,results:[1 0 0]
# question1:                     turning point in your life
# question2:                 when do  reach turning point in my life
# indix:5230,results:[1 0 0]
# question1:                     how can  immigrate america
# question2:                  how can  go live work in us
# indix:5279,results:[1 0 0]
# question1:                      no do in singapore
# question2:                  should  not do when  visit singapore
# indix:5280,results:[1 0 0]
# question1:                      how simplilearn online classes
# question2:                   can anyone provide review simplilearn online courses
# indix:5298,results:[1 0 0]
# question1:                       are encryption standards
# question2:                         encryption
# indix:5316,results:[1 0 0]
# question1:           have you ever got out movie theater in middle movie you didn t like it
# question2:                has movie ever been bad you walked out movie theater
# indix:5344,results:[1 0 0]
# question1:                why does holden caulfield lie in catcher in rye purpose
# question2:             do you think all lies holden caulfield told in book catcher in rye
# indix:5431,results:[1 0 0]
# question1:                 how do  become better thinker innovator problem solver
# question2:               how can  become more creative interdisciplinary in my problem solving
# indix:5460,results:[1 0 0]
# question1:                      intuitive explanation bootstrap UNK
# question2:                    intuitive explanation bootstrap sampling in statistics
# indix:5473,results:[1 0 0]
# question1:                   are best ways determine roi social media
# question2:                   best way measure roi social media marketing
# indix:5490,results:[1 0 0]
# question1:                   where can  get lsd in pune
# question2:                  how do  get lsd stamps in pune
# indix:5502,results:[1 0 0]
# question1:                    does donald trump think himself UNK
# question2:                       donald trump UNK
# indix:5527,results:[1 0 0]
# question1:                        halloween tradition
# question2:                     are some great halloween traditions
# indix:5542,results:[1 0 0]
# question1:               zombie outbreak apocalypse happened would be best 15 weapons be safe
# question2:                      best zombie killing weapon
# indix:5569,results:[1 0 0]
# question1:                      how startup get funding
# question2:                  are best ways get startup funding in india
# indix:5613,results:[1 0 0]
# question1:                   have leopard seals been known attack man
# question2:                    are leopard seals dangerous towards humans
# indix:5619,results:[1 0 0]
# question1:                   how do  hack facebook on android
# question2:                     how can  hack facebook
# indix:5638,results:[1 0 0]
# question1:                     who publishes world book encyclopedia
# question2:                     who wrote world book encyclopedia
# indix:5725,results:[1 0 0]
# question1:                      are chemical engineering salary
# question2:                       salary chemical engineers
# indix:5749,results:[1 0 0]
# question1:                   how can  grow full beard naturally
# question2:                how can  grow full beard  have UNK one
# indix:5758,results:[1 0 0]
# question1:                    best way cook frozen roast beef
# question2:                   are some best ways cook frozen beef
# indix:5786,results:[1 0 0]
# question1:                    your review skins england tv series
# question2:                    your review office england tv series
# indix:5808,results:[1 0 0]
# question1:                 are some ways people cope with depression graduate school
# question2:            how do people with clinical depression cope with stress should they avoid stressful jobs
# indix:5823,results:[1 0 0]
# question1:                  why do you think people fall in love
# question2:                    why do people fall in love
# indix:5857,results:[1 0 0]
# question1:                    s it like living in montenegro
# question2:                     it like live in montenegro
# indix:5927,results:[1 0 0]
# question1:                    why are all twilight movies bad
# question2:                    why acting in twilight movies bad
# indix:6041,results:[1 0 0]
# question1:               how do UNK mobile phone hp laptop it s not connecting
# question2:              how do  connect mobile phone hp laptop it s not connecting
# indix:6047,results:[1 0 0]
# question1:                  how should  start preparing civil services exam
# question2:                  how should  start my preparation ias exam
# indix:6092,results:[1 0 0]
# question1:                        accuracy precision
# question2:                    how does accuracy differ from precision
# indix:6149,results:[1 0 0]
# question1:                  why does something bad happen after something good
# question2:                  when something good happens something bad happens why
# indix:6184,results:[1 0 0]
# question1:                      greatest mystery in earth
# question2:                      greatest mystery in universe
# indix:6188,results:[1 0 0]
# question1:                      are best viral videos
# question2:                       best viral video
# indix:6227,results:[1 0 0]
# question1:                   were best books you read in 2016
# question2:                    best book you read in 2015
# indix:6232,results:[1 0 0]
# question1:           do undecided voters think hillary clinton s dnc speech are they UNK in any way
# question2:            do you think hillary clinton s acceptance speech at 2016 dnc were main themes
# indix:6246,results:[1 0 0]
# question1:                  how could  improve my love my girlfriend
# question2:                how can  keep my girlfriend in love with me
# indix:6271,results:[1 0 0]
# question1:                   how can  get online job programmer
# question2:                    how can  get online job
# indix:6339,results:[1 0 0]
# question1:                      difference between act scene
# question2:                   s difference between act scene in play
# indix:6347,results:[1 0 0]
# question1:                  how do  turn off screen overlay android
# question2:                   how do  turn off screen overlay
# indix:6447,results:[1 0 0]
# question1:                 can  get some ideas on advertising products presentation
# question2:                  can  get some ideas on advertising products
# indix:6555,results:[1 0 0]
# question1:                     can dentists be called doctors
# question2:                    why are dentists not considered doctors
# indix:6564,results:[1 0 0]
# question1:                     do you think UNK net
# question2:                     do you think UNK net
# indix:6584,results:[1 0 0]
# question1:                         stone
# question2:                         stone
# indix:6599,results:[1 0 0]
# question1:                  are some good songs make texting lyric prank
# question2:                  are some good songs lyric prank your boyfriend
# indix:6683,results:[1 0 0]
# question1:                  would world be like banks had never existed
# question2:                   money would world without money be like
# indix:6743,results:[1 0 0]
# question1:                    are best ski resorts in tahoe
# question2:                     best lake tahoe ski resort
# indix:6847,results:[1 0 0]
# question1:               there any way recover e mails were deleted from gmail account
# question2:         there any way by we can get message back deleted from inbox well from trash on gmail
# indix:6918,results:[1 0 0]
# question1:                      it good be good
# question2:                     why it good be good
# indix:6928,results:[1 0 0]
# question1:                    how racist south in u s
# question2:                   west point u s army whole racist
# indix:6969,results:[1 0 0]
# question1:                    how many people have ever lived
# question2:                  rough estimate total number humans have ever lived
# indix:6979,results:[1 0 0]
# question1:                    how can  meet parineeti chopra
# question2:                   how it meet parineeti chopra in person
# indix:6999,results:[1 0 0]
# question1:                   how do you calculate taxes on calculator
# question2:                   how can you calculate taxes on calculator
# indix:7089,results:[1 0 0]
# question1:                  hav capital 20 lacs business can  start
# question2:                   business should  start with 20 lac
# indix:7101,results:[1 0 0]
# question1:                      keeps you inspired always
# question2:                      who keeps you inspired
# indix:7104,results:[1 0 0]
# question1:                    there anyway  can grow taller
# question2:                      can  grow taller
# indix:7148,results:[1 0 0]
# question1:                       mean by rectifier
# question2:                         rectifier
# indix:7193,results:[1 0 0]
# question1:                how submarine canyon formed difference between ocean deep submarine canyon
# question2:                    difference between ocean deep submarine canyon
# indix:7197,results:[1 0 0]
# question1:                   are some good opening steps in chess
# question2:                   are best most effective openings in chess
# indix:7272,results:[1 0 0]
# question1:             are some good places visit in chennai when you re all by yourself
# question2:                   are some great places visit in chennai
# indix:7374,results:[1 0 0]
# question1:            why don t we quit voting let president rule be implemented all over india
# question2: indian politicians they are all using us run their train still they win elections rule over us why aren t people giving their vote nota
# indix:7417,results:[1 0 0]
# question1:                     how does business insurance work
# question2:                    how do insurance companies make money
# indix:7450,results:[1 0 0]
# question1:                      great leonardo da vinci
# question2:                    are facts fiction leonardo da vinci
# indix:7492,results:[1 0 0]
# question1:              how far jupiter from sun how does its proximity affect planets characteristics
# question2:              how far pluto from sun how does its proximity affect planets characteristics
# indix:7544,results:[1 0 0]
# question1:                  how do  reduce thigh thickness hip thickness
# question2:                  exercise can help me reduce my thigh fat
# indix:7696,results:[1 0 0]
# question1:                      does business consultant do
# question2:                       do consultants do
# indix:7705,results:[1 0 0]
# question1:                      how pressure intensive property
# question2:                      why pressure intensive property
# indix:7788,results:[1 0 0]
# question1:                     how do  clear cat
# question2:                     does it take clear cat
# indix:7881,results:[1 0 0]
# question1:                    how do  teach class student
# question2:                    how should  teach my students
# indix:7978,results:[1 0 0]
# question1:              all oceans were replaced with gasoline match was thrown in would happen
# question2:                  would happen there were no oceans on earth
# indix:8003,results:[1 0 0]
# question1:                    are some weirdest guinness world records
# question2:                    are some craziest guinness world records
# indix:8011,results:[1 0 0]
# question1:                   how can we learn make humanoid robots
# question2:                 how can  make humanoid robot control our brain
# indix:8024,results:[1 0 0]
# question1:                     does oppo f1s support 4g
# question2:                     does oppo f1s support 3g
# indix:8092,results:[1 0 0]
# question1:                     should  do after diploma
# question2:                  wasted 2 years after diploma should  do
# indix:8095,results:[1 0 0]
# question1:                  s your favorite photograph taken by you why
# question2:                     best picture taken by you
# indix:8126,results:[1 0 0]
# question1:                  how much do piles surgery cost in india
# question2:                  how much does lip surgery cost in india
# indix:8176,results:[1 0 0]
# question1:                   how can one learn adsense adwords online
# question2:                    how can one learn adsense adwords
# indix:8202,results:[1 0 0]
# question1:                         entropy
# question2:                       meant by entropy
# indix:8367,results:[1 0 0]
# question1:                   world after death recorded in scripture UNK
# question2:                     happens after death according sikhism
# indix:8442,results:[1 0 0]
# question1:                    who your favorite character from naruto
# question2:                   who your least favorite character in naruto
# indix:8466,results:[1 0 0]
# question1:                   are books one must read in life
# question2:                     are best books all time
# indix:8576,results:[1 0 0]
# question1:                  why do  fail at dating all time
# question2:                       why dating hard
# indix:8595,results:[1 0 0]
# question1:                       bulletproof coffee good
# question2:                  has bulletproof coffee worked who have drunk it
# indix:8598,results:[1 0 0]
# question1:                    are best colleges bca in mumbai
# question2:                    are best colleges bba in mumbai
# indix:8617,results:[1 0 0]
# question1:                   why can t we make time machine
# question2:                     it possible make time machine
# indix:8730,results:[1 0 0]
# question1:                 are some secrets girls rarely share with any boy
# question2:               are some secrets girl would rarely be fond sharing with boy
# indix:8755,results:[1 0 0]
# question1:                   401 k plan how does it work
# question2:                   401 000 plan how does it work
# indix:8765,results:[1 0 0]
# question1:                 it true each royal enfield s tanks are UNK
# question2:                    are royal enfield tanks hand painted
# indix:8837,results:[1 0 0]
# question1:                    zeus still powerful without his UNK
# question2:                    zeus powerful without his UNK why
# indix:9015,results:[1 0 0]
# question1:                  best way know how sincere someone loves you
# question2:                   how do  know someone loves you
# indix:9093,results:[1 0 0]
# question1:                    are best places visit near kolhapur
# question2:                    are best places visit near UNK
# indix:9133,results:[1 0 0]
# question1:                       business model zipcar
# question2:                     business model does zipcar practice
# indix:9134,results:[1 0 0]
# question1:                  who are top mobile app developers in india
# question2:                   are best app development companies in india
# indix:9182,results:[1 0 0]
# question1:                     procedure cancel my passport application
# question2:                    can  cancel my passport application
# indix:9222,results:[1 0 0]
# question1:                   popular quora user balaji viswanathan modi bhakt
# question2:                      balaji viswanathan modi bhakt
# indix:9292,results:[1 0 0]
# question1:                     who worst indian actor ever
# question2:                      who worst actor bollywood
# indix:9309,results:[1 0 0]
# question1:     ok ladies someone offered u 50 dollars take pictures your feet in pantyhose send it their phone would u do it
# question2:       ladies were offered 50 take pictures your feet in pantyhose send it someone s phone would you do it
# indix:9360,results:[1 0 0]
# question1:                      feminism good population control
# question2:                      feminism population controlling tool
# indix:9397,results:[1 0 0]
# question1:                   should  apply pan card online offline
# question2:             how do  apply receive pan card in 48 hours with new facilities
# indix:9439,results:[1 0 0]
# question1:            despite several failures why does america keep interfering with internal domestic affairs other countries
# question2:                why does america keep on interfering in other countries matters
# indix:9442,results:[1 0 0]
# question1:                   how often should you apply face mask
# question2:                  how many times should  use face mask
# indix:9501,results:[1 0 0]
# question1:                   how can  stop being scared rejection
# question2:                    how can  stop getting scared
# indix:9506,results:[1 0 0]
# question1:                are 7th chords more commonly played major 7th chords why
# question2:                 are 7th chords more commonly played major 7th chords
# indix:9509,results:[1 0 0]
# question1:             can  make 30 million dollars day trading  start with 500 000
# question2:            can  make 30 million dollars day trading  start with 500 000 how
# indix:9530,results:[1 0 0]
# question1:                    are facials good bad your skin
# question2:                   are cosmetic facials actually good your skin
# indix:9700,results:[1 0 0]
# question1:                    are renewable resources are some examples
# question2:                     are examples nonrenewable renewable resources
# indix:9720,results:[1 0 0]
# question1:               would happen you hired two private detectives spy on each other
# question2:                will happen  hire two private detectives follow each other
# indix:9805,results:[1 0 0]
# question1:                  are best resources learn programming at its core
# question2:                     best resource learn c programming
# indix:9861,results:[1 0 0]
# question1:                    best phone buy below 6 000
# question2:                    best phone buy below 15 000
# indix:9887,results:[1 0 0]
# question1:                      does post secondary means
# question2:                      are post secondary courses

# %%
train_pairs = pd.read_csv('/Users/zhang/MscProject_tweak2vec/QuoraQuestionPairs/train.csv',encoding='ISO-8859-1')
pd.options.display.max_colwidth=200

# %%
where1 = np.where(train_pairs['question1'].str.contains('sugar'), 1, 0)
where2 = np.where(train_pairs['question1'].str.contains('you'), 1, 0)
ids = []
for i in range(len(where1)):
    if where1[i] == 1 and where2[i] == 1:
            ids.append(i)
train_pairs.loc[ids]
# Out:
#             id    qid1    qid2  \
# 316        316     632     633
# 8936      8936   17392   17393
# 46063    46063   82437   82438
# 49806    49806   88602   88603
# 50075    50075   89025   89026
# 57474    57474  100990  100991
# 88182    88182  148364  148365
# 99279    99279   88602  164840
# 106283  106283  175111  175112
# 200736  200736  148364  292983
# 201635  201635  303690  176555
# 248511  248511  361954  361955
# 249621  249621  363293  148364
# 257257  257257  372529  372530
# 259640  259640  375437  375438
# 275228  275228  393989  393990
# 295739  295739  417831  417832
# 323052  323052  448970  362633
# 326424  326424   88603  164840
# 362332  362332  492231  492232
# 363362  363362  493340  493341
#
#                                                                                                                                                     question1  \
# 316                                                                  What does this saying mean; "Don't trust everything you see even salt looks like sugar"?
# 8936                                                                                                          Can you substitue brown sugar with white sugar?
# 46063                                                                                                What would happen if you cut out refined sugar entirely?
# 49806                                                                                                          Does consuming sugar lower your immune system?
# 50075                                                                                             How can mouthwash be sweet? Isn't sugar bad for your teeth?
# 57474   Does eating too much sugar give you diabetes? I actually do work out and eat healthy for the most part but I'm wondering because I eat a lot of sugar
# 88182                                                                                                                               Why is sugar bad for you?
# 99279                                                                                                          Does consuming sugar lower your immune system?
# 106283                                                                                                                        How can you find a sugar daddy?
# 200736                                                                                                                              Why is sugar bad for you?
# 201635                                I read on a wiki that you can remove gel nail polish by heating up sugar and then holding your nails in it. Is it true?
# 248511                                                                                                   Can you have low blood sugar without being diabetic?
# 249621                                              If our bodies run on sugar, and things like carbs just get converted to sugars, why is sugar bad for you?
# 257257                                                                                Can you substitute granulated sugar for powdered sugar? Why or why not?
# 259640                                                                                                       Can you get diabetic from eating too much sugar?
# 275228                                                                                                    How do you make an Apple crisp without brown sugar?
# 295739                                                                   What does a sugar glider eat? How do you plan a healthy diet for a pet sugar glider?
# 323052                                                                                                      Should you drink green tea with or without sugar?
# 326424                                                                          How does consuming too much sugar on a daily basis weaken your immune system?
# 362332                                                                                                                    How do you break a sugar addiction?
# 363362                                                                                                                                                    NaN
#
#                                                                                                                                             question2  \
# 316                                                            People say "don't try to please others." Does being nice to others mean pleasing them?
# 8936                                                                                                          Can I substitute white sugar for brown?
# 46063                                                           How can I get accutane in London and how expensive is it when using a private doctor?
# 49806                                                                   How does consuming too much sugar on a daily basis weaken your immune system?
# 50075                                                                                                                     Is spaghetti bad for teeth?
# 57474                                                                    Does eating too much sugar actually give you an increased risk for diabetes?
# 88182                                                                                                                    Why sugar is bad for health?
# 99279                                                                                     Does sugar suppress the effectiveness of the immune system?
# 106283                                                                                                                How do I acquire a sugar daddy?
# 200736                                                                                                                       Why is sugar bad for us?
# 201635                                                                                                               How can I remove gel nail paint?
# 248511                                                                                                      What can low blood sugar do to your body?
# 249621                                                                                                                      Why is sugar bad for you?
# 257257                                                                                    How can you substitute granulated sugar for powdered sugar?
# 259640  Can you get Type 2 diabetes from eating too much sugar? Type 2 diabetes is a life long disease that can't be stop unless going to the doctor.
# 275228                                                              Can you use brown sugar to make brownies? What are the health values of doing so?
# 295739                                                                                                               What foods do sugar gliders eat?
# 323052                                                                                                                  Why should I drink green tea?
# 326424                                                                                    Does sugar suppress the effectiveness of the immune system?
# 362332                                                                                                          How does one break a sugar addiction?
# 363362                    My Chinese name is Haichao Yu. What English name is most suitable for me considering the pronounciation of my Chinese name?
#
#         is_duplicate
# 316                0
# 8936               1
# 46063              0
# 49806              1
# 50075              0
# 57474              1
# 88182              1
# 99279              1
# 106283             1
# 200736             1
# 201635             0
# 248511             0
# 249621             1
# 257257             1
# 259640             1
# 275228             0
# 295739             1
# 323052             0
# 326424             1
# 362332             0
# 363362             0

# %%
w1 = 'obama'
w2 = 'putin'
vec1 = embed_reg[word2idx[w1]].reshape(-1,1)
vec2 = embed_reg[word2idx[w2]].reshape(-1,1)
def cosin_distance(vector1, vector2):
    dot_product = 0.0
    normA = 0.0
    normB = 0.0
    for a, b in zip(vector1, vector2):
        dot_product += a * b
        normA += a ** 2
        normB += b ** 2
    if normA == 0.0 or normB == 0.0:
        return None
    else:
        return np.abs(dot_product / ((normA * normB) ** 0.5))
cosin_distance(vec1, vec2)
# Out:
# array([0.72424675])
